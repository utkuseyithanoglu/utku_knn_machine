# %% [markdown]
# <a href="https://colab.research.google.com/github/utkuseyithanoglu/utku_knn_machine/blob/main/src/explore-5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 1. GitHub Projenizi Klonlayın
#
# Öncelikle, GitHub projenizi Colab'a klonlamanız gerekecek. Bunun için projenizin URL'sine ihtiyacınız var. Aşağıdaki kodu kullanarak klonlama işlemini yapabilirsiniz. "YOUR_GITHUB_REPO_URL" kısmını projenizin URL'si ile değiştirmeyi unutmayın.

# %%
# !git clone https://github.com/utkuseyithanoglu/utku_knn_machine
# Out:
# Cloning into 'utku_knn_machine'...
# remote: Enumerating objects: 52, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 52 (delta 12), reused 23 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (52/52), 4.81 MiB | 14.94 MiB/s, done.
# Resolving deltas: 100% (12/12), done.

# %% [markdown]
# ### 2. Proje Klasörüne Girin
#
# Klonlama işlemi tamamlandıktan sonra, projenizin klasörüne gitmeniz gerekiyor. Genellikle projenizin adı ile aynı isimde bir klasör oluşur. Aşağıdaki kodu kullanarak o klasöre geçin. "YOUR_REPO_NAME" kısmını klonladığınız projenizin adıyla değiştirin.

# %%
# %cd utku_knn_machine

# %% [markdown]
# ### 3. Değişikliklerinizi Yapın
#
# Artık projenizin dosyalarını Colab'da düzenleyebilirsiniz. Örneğin, Python dosyalarını açıp değiştirebilir veya yeni dosyalar oluşturabilirsiniz. Dosyaları düzenlemek için Jupyter arayüzünü (sol paneldeki dosya simgesi) kullanabilirsiniz.

# %% [markdown]
# ### 4. Değişikliklerinizi GitHub'a Gönderin (Commit ve Push)
#
# Değişikliklerinizi tamamladıktan sonra, bunları GitHub'a geri göndermeniz gerekir. Bunun için Git komutlarını kullanacağız:
#
# *   **`git add .`**: Tüm değişiklikleri sahnelemeye alır.
# *   **`git commit -m "Değişikliklerinizin açıklaması"`**: Değişikliklerinizi bir mesajla kaydedin.
# *   **`git push`**: Değişikliklerinizi GitHub'a gönderin.
#
# Bu adımlar için GitHub kimlik bilgilerinizin (kullanıcı adı ve kişisel erişim jetonu) doğru şekilde yapılandırılması gerekebilir. Eğer ilk defa yapıyorsanız, `git config --global user.email "you@example.com"` ve `git config --global user.name "Your Name"` komutlarıyla e-posta ve isminizi ayarlamanız iyi olacaktır.

# %%
# Örnek: Değişikliklerinizi yapıp bu hücreyi çalıştırın.

# git add .
# git commit -m "Örnek bir değişiklik yaptım"
# git push

# GitHub'a push yaparken kimlik bilgilerinizi girmeniz istenebilir.
