# %% [markdown]
# # Explore here

# %%
# Your code here
# Your code here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)

# %%
main_df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv",sep=';')
main_df1 = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv",sep=";")

# %%
main_df['color'] = 'red'
main_df1['color'] = 'white'

# %%
my_df= pd.concat([main_df,main_df1])

# %%
my_df= pd.get_dummies(my_df,dtype=int,drop_first=True)

# %%
my_df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# color_white             0
# dtype: int64

# %%
my_df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
my_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6497 entries, 0 to 4897
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   float64
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6497 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6497 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
#  12  color_white           6497 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 710.6 KB

# %%
#i want a look correlation because after the make a predict if its not good i wil be a doing feature engineriing
my_df.corr()['quality']
# Out:
# fixed acidity          -0.076743
# volatile acidity       -0.265699
# citric acid             0.085532
# residual sugar         -0.036980
# chlorides              -0.200666
# free sulfur dioxide     0.055463
# total sulfur dioxide   -0.041385
# density                -0.305858
# pH                      0.019506
# sulphates               0.038485
# alcohol                 0.444319
# quality                 1.000000
# color_white             0.119323
# Name: quality, dtype: float64

# %%
my_df.corr()['quality']
# Out:
# fixed acidity          -0.076743
# volatile acidity       -0.265699
# citric acid             0.085532
# residual sugar         -0.036980
# chlorides              -0.200666
# free sulfur dioxide     0.055463
# total sulfur dioxide   -0.041385
# density                -0.305858
# pH                      0.019506
# sulphates               0.038485
# alcohol                 0.444319
# quality                 1.000000
# color_white             0.119323
# Name: quality, dtype: float64

# %%
# i am gone look heatmap the make relatihonship the feature
sns. heatmap(data=my_df.corr())
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split

# %%
train_df,test_df = train_test_split(my_df)

# %%
test_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4793            6.0              0.31         0.32             7.4      0.175
# 1228            5.1              0.42         0.00             1.8      0.044
# 434            10.4              0.41         0.55             3.2      0.076
# 2853            5.3              0.16         0.39             1.0      0.028
# 2486            6.7              0.24         0.32            10.3      0.079
# ...             ...               ...          ...             ...        ...
# 4376            6.1              0.34         0.21             5.0      0.042
# 4803            6.4              0.31         0.50             5.8      0.038
# 1431            7.6              0.43         0.31             2.1      0.069
# 2322            6.1              0.41         0.04             1.3      0.036
# 3318            6.6              0.16         0.35             1.8      0.042
#
# ...

# %%
sns.histplot(data=train_df,x='fixed acidity',hue='quality')
# Out:
# <Axes: xlabel='fixed acidity', ylabel='Count'>

# %%
sns.scatterplot(data=train_df,x='fixed acidity',y='volatile acidity',hue='quality')
# Out:
# <Axes: xlabel='fixed acidity', ylabel='volatile acidity'>

# %%
#looks like 15 16 outlier i need to check barplot so i am doig the all eda because i want a know is there any outlier

# %%
sns.barplot(data=train_df,x='fixed acidity',hue='quality')
# Out:
# <Axes: xlabel='fixed acidity'>

# %% [markdown]
# i found a outlier but i wanta a learn z score so i want a try z score

# %%
from scipy import stats

# %%
pd.DataFrame(train_df['fixed acidity'][stats.zscore(train_df['fixed acidity']) > 3]).sort_values(by='fixed acidity',ascending=True)
# Out:
#       fixed acidity
# 507            11.2
# 3              11.2
# 1020           11.3
# 455            11.3
# 667            11.3
# ...             ...
# 555            15.5
# 554            15.5
# 442            15.6
# 557            15.6
# 652            15.9
#
# [95 rows x 1 columns]

# %% [markdown]
# i choose log

# %%
(train_df['fixed acidity']==0).sum()
print((test_df['fixed acidity']==0).sum())
# Out:
# 0

# %%
train_main_quality = train_df[train_df['quality']==5]
train_3_quality = train_df[train_df['quality']==3]
train_4_quality = train_df[train_df['quality']==4]
train_6_quality = train_df[train_df['quality']==6]
train_7_quality = train_df[train_df['quality']==7]
train_8_quality = train_df[train_df['quality']==8]
#this code made a correct imbalance data

# %%
resampled__quality = train_3_quality.sample(n = round(len(train_main_quality)),
                          replace=True)

resampled__quality1 = train_4_quality.sample(n = round(len(train_main_quality)),
                          replace=True)

resampled__quality2 = train_6_quality.sample(n = round(len(train_main_quality)),
                          replace=True)
resampled__quality3 = train_7_quality.sample(n=round(len(train_main_quality)),
                                             replace=True)

resampled__quality4 = train_8_quality.sample(n = round(len(train_main_quality) ),
                          replace=True)

# %%
os_train_df = pd.concat([train_main_quality, resampled__quality,resampled__quality1,resampled__quality2,resampled__quality3, \
                                  resampled__quality4])
os_train_df['quality'].value_counts(normalize=True)
# Out:
# quality
# 5    0.166667
# 3    0.166667
# 4    0.166667
# 6    0.166667
# 7    0.166667
# 8    0.166667
# Name: proportion, dtype: float64

# %%
os_train_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4542            6.9             0.280         0.37            9.10      0.037
# 208             6.8             0.570         0.29            2.20      0.040
# 393             8.4             0.665         0.61            2.00      0.112
# 2650            7.0             0.340         0.39            6.90      0.066
# 4236            6.4             0.290         0.18           15.00      0.040
# ...             ...               ...          ...             ...        ...
# 4335            7.3             0.190         0.27           13.90      0.057
# 22              6.8             0.260         0.42            1.70      0.049
# 2945            4.9             0.330         0.31            1.20      0.016
# 1797            6.9             0.250         0.27            9.05      0.039
# 783             8.1             0.170         0.44           14.10      0.053
#
# ...

# %%
# i need. the fix outlier 
os_train_df['fixed acidity'] = np.log(os_train_df['fixed acidity'])
test_df['fixed acidity'] = np.log(test_df['fixed acidity'])

# %%
os_train_df['volatile acidity'].value_counts()
# Out:
# volatile acidity
# 0.260    514
# 0.240    430
# 0.230    420
# 0.320    413
# 0.280    322
#         ...
# 0.605      1
# 0.115      1
# 0.355      1
# 0.085      1
# 0.790      1
# Name: count, Length: 168, dtype: int64

# %%
pd.DataFrame(os_train_df.groupby('volatile acidity')['quality'].value_counts())
# Out:
#                           count
# volatile acidity quality
# 0.080            6            3
# 0.085            6            1
# 0.100            7            7
#                  6            2
#                  5            1
# ...                         ...
# 1.115            4            5
# 1.180            5            1
# 1.240            5            1
# 1.330            5            2
# 1.580            3           61
#
# [455 rows x 1 columns]

# %%
sns.scatterplot(data=train_df,x='volatile acidity',y='citric acid',hue='quality')
# Out:
# <Axes: xlabel='volatile acidity', ylabel='citric acid'>

# %%
sns.barplot(data=train_df,x='volatile acidity',hue='quality')
# Out:
# <Axes: xlabel='volatile acidity'>

# %%
sns.boxplot(data=train_df,x='volatile acidity',hue='quality')
# Out:
# <Axes: xlabel='volatile acidity'>

# %%
pd.DataFrame(train_df['volatile acidity'][stats.zscore(train_df['volatile acidity']) > 3]).sort_values(by='volatile acidity',ascending=True)
# this code is doig zscore if its higer than 3 it is possibly oversampling
# Out:
#       volatile acidity
# 602              0.835
# 732              0.835
# 429              0.840
# 659              0.840
# 635              0.840
# ...                ...
# 1312             1.180
# 672              1.240
# 127              1.330
# 126              1.330
# 1299             1.580
#
# [72 rows x 1 columns]

# %%
print((os_train_df['volatile acidity']==0).sum())
print((test_df['volatile acidity']==0).sum())
#this code looks is there any 0 value because i want a use log
# Out:
# 0
# 0

# %%
os_train_df['volatile acidity'] = np.log(os_train_df['volatile acidity'])
test_df['volatile acidity'] = np.log(test_df['volatile acidity'])

# %%
train_df['citric acid']
# Out:
# 4542    0.37
# 208     0.29
# 393     0.61
# 2650    0.39
# 4236    0.18
#         ...
# 2897    0.46
# 709     0.21
# 3534    0.35
# 3830    0.23
# 1296    0.33
# Name: citric acid, Length: 4872, dtype: float64

# %%
pd.DataFrame(os_train_df.groupby('residual sugar')['quality'].value_counts())
# Out:
#                         count
# residual sugar quality
# 0.60           5            2
# 0.70           3           79
#                4            8
#                5            3
# 0.80           4           33
# ...                       ...
# 20.80          6            2
# 22.00          5            1
# 22.60          5            1
# 26.05          6            3
# 31.60          6            1
#
# [712 rows x 1 columns]

# %%
sns.histplot(data=os_train_df,x='residual sugar',hue='quality',multiple='stack')
# Out:
# <Axes: xlabel='residual sugar', ylabel='Count'>

# %%
sns.scatterplot(data=os_train_df,x='volatile acidity',y='residual sugar',hue='quality')
# Out:
# <Axes: xlabel='volatile acidity', ylabel='residual sugar'>

# %%
sns.barplot(data=train_df,x='residual sugar',hue='quality')
# Out:
# <Axes: xlabel='residual sugar'>

# %%
pd.DataFrame(train_df['residual sugar'][stats.zscore(train_df['residual sugar']) > 3]).sort_values(by='residual sugar',ascending=True)
# Out:
#       residual sugar
# 1775           19.60
# 1454           19.80
# 3023           19.80
# 292            19.80
# 3547           19.90
# 3497           19.95
# 2492           19.95
# 3420           20.15
# 2785           20.20
# 2620           20.40
# 7              20.70
# 3730           20.80
# 444            20.80
# 182            22.00
# 4480           22.60
# 3619           26.05
# 3623           26.05
# 1663           31.60

# %%
print((os_train_df['residual sugar']==0).sum())
print((test_df['residual sugar']==0).sum())
# Out:
# 0
# 0

# %%
os_train_df['residual sugar'] = np.log(os_train_df['residual sugar'])
test_df['residual sugar'] = np.log(test_df['residual sugar'])

# %%
pd.DataFrame(os_train_df.groupby('chlorides')['quality'].value_counts())
# Out:
#                    count
# chlorides quality
# 0.009     5            1
# 0.012     7            3
# 0.014     7            3
#           4            2
# 0.016     8           11
# ...                  ...
# 0.414     5            1
# 0.415     5            2
# 0.464     5            1
# 0.467     5            1
# 0.611     5            1
#
# [493 rows x 1 columns]

# %%
sns.scatterplot(data=train_df,x='chlorides',y='free sulfur dioxide',hue='quality')
# Out:
# <Axes: xlabel='chlorides', ylabel='free sulfur dioxide'>

# %%
sns.histplot(data=os_train_df,x='chlorides',hue='quality',multiple='stack')
# Out:
# <Axes: xlabel='chlorides', ylabel='Count'>

# %%
sns.barplot(data=train_df,x='chlorides',hue='quality')
# Out:
# <Axes: xlabel='chlorides'>

# %%
sns.boxplot(data=train_df,x='chlorides',hue='quality')
# Out:
# <Axes: xlabel='chlorides'>

# %%
pd.DataFrame(train_df['chlorides'][stats.zscore(train_df['chlorides']) > 3]).sort_values(by='chlorides',ascending=True)
# Out:
#       chlorides
# 916       0.161
# 1191      0.166
# 1193      0.166
# 3737      0.167
# 1599      0.167
# ...         ...
# 754       0.415
# 1372      0.415
# 81        0.464
# 106       0.467
# 258       0.611
#
# [82 rows x 1 columns]

# %%
print((os_train_df['chlorides']==0).sum())
print((test_df['chlorides']==0).sum())
# Out:
# 0
# 0

# %%
os_train_df['chlorides'] = np.log(os_train_df['chlorides'])
test_df['chlorides'] = np.log(test_df['chlorides'])

# %%
pd.DataFrame(os_train_df.groupby('free sulfur dioxide')['quality'].value_counts())
# Out:
#                              count
# free sulfur dioxide quality
# 1.0                 6            3
# 2.0                 5            1
# 3.0                 3           74
#                     4           42
#                     7           24
# ...                            ...
# 122.5               4           10
# 124.0               3           68
# 128.0               5            1
# 131.0               5            1
# 289.0               3           53
#
# [372 rows x 1 columns]

# %%
sns.histplot(data=os_train_df,x='free sulfur dioxide',hue='quality',multiple='stack')
# Out:
# <Axes: xlabel='free sulfur dioxide', ylabel='Count'>

# %%
sns.scatterplot(data=os_train_df,x='free sulfur dioxide',y='total sulfur dioxide',hue='quality')
# Out:
# <Axes: xlabel='free sulfur dioxide', ylabel='total sulfur dioxide'>

# %%
print((os_train_df['free sulfur dioxide']==0).sum())
print((test_df['free sulfur dioxide']==0).sum())
# Out:
# 0
# 0

# %% [markdown]
# this dot is too obivous too outlier

# %%
os_train_df['free sulfur dioxide'] = np.log(os_train_df['free sulfur dioxide'])
test_df['free sulfur dioxide'] = np.log(test_df['free sulfur dioxide'])

# %%
pd.DataFrame(os_train_df.groupby('total sulfur dioxide')['quality'].value_counts())
# Out:
#                               count
# total sulfur dioxide quality
# 6.0                  5            2
# 7.0                  7            2
#                      6            1
# 8.0                  4           11
#                      7           10
# ...                             ...
# 303.0                5            1
# 313.0                5            1
# 344.0                5            1
# 366.5                3           72
# 440.0                3           53
#
# [849 rows x 1 columns]

# %%
sns.scatterplot(data=train_df,x='total sulfur dioxide',y='density',hue='quality')
plt.grid()

# %%
sns.histplot(data=os_train_df,x='total sulfur dioxide',hue='quality',multiple='stack')
# Out:
# <Axes: xlabel='total sulfur dioxide', ylabel='Count'>

# %%
sns.boxplot(data=train_df,x='total sulfur dioxide',hue='quality')
# Out:
# <Axes: xlabel='total sulfur dioxide'>

# %%
pd.DataFrame(train_df['total sulfur dioxide'][stats.zscore(train_df['total sulfur dioxide']) > 3]).sort_values(by='total sulfur dioxide',ascending=True)
# Out:
#       total sulfur dioxide
# 3152                 294.0
# 2654                 303.0
# 325                  313.0
# 2127                 344.0
# 1417                 366.5
# 4745                 440.0

# %%
(os_train_df['total sulfur dioxide']==0).sum()
# Out:
# np.int64(0)

# %%
os_train_df['total sulfur dioxide']=np.log(os_train_df['total sulfur dioxide'])
test_df['total sulfur dioxide'] = np.log(test_df['total sulfur dioxide'])

# %%
pd.DataFrame(os_train_df.groupby('density')['quality'].value_counts())
# Out:
#                  count
# density quality
# 0.98713 8           11
# 0.98722 5            1
# 0.98740 5            1
# 0.98746 7            2
# 0.98758 6            1
# ...                ...
# 1.00289 5            1
# 1.00295 6            3
# 1.00315 5            3
# 1.00369 6            3
# 1.01030 6            1
#
# [1540 rows x 1 columns]

# %%
sns.scatterplot(data=train_df,x='density',y='pH',hue='quality')
# Out:
# <Axes: xlabel='density', ylabel='pH'>

# %% [markdown]
# the dot is too obivous but u want a make z-score

# %%
sns.boxplot(data=train_df,x='density',hue='quality')
# Out:
# <Axes: xlabel='density'>

# %%
sns.histplot(data=train_df,x='density',hue='quality')
# Out:
# <Axes: xlabel='density', ylabel='Count'>

# %%
pd.DataFrame(train_df['density'][stats.zscore(train_df['density']) > 3]).sort_values(by='density',ascending=True)
# Out:
#       density
# 1434  1.00369
# 1663  1.01030

# %%
print((os_train_df['density']==0).sum())
(test_df['density']==0).sum()
# Out:
# 0
# np.int64(0)

# %%
os_train_df['density']=np.log(os_train_df['density'])
test_df['density'] = np.log(test_df['density'])

# %%
pd.DataFrame(os_train_df.groupby('pH')['quality'].value_counts())
# Out:
#               count
# pH   quality
# 2.72 6            1
# 2.74 6            1
# 2.77 6            1
# 2.79 5            2
# 2.80 5            1
# ...             ...
# 3.79 5            1
# 3.81 6            1
# 3.82 7            1
# 3.90 4           10
# 4.01 6            1
#
# [393 rows x 1 columns]

# %%
sns.scatterplot(data=train_df,x='pH',y='sulphates',hue='quality')
# Out:
# <Axes: xlabel='pH', ylabel='sulphates'>

# %%
sns.histplot(data=os_train_df,x='pH',hue='quality',multiple='stack')
# Out:
# <Axes: xlabel='pH', ylabel='Count'>

# %%
sns.boxplot(data=train_df,x='pH',hue='quality')
# Out:
# <Axes: xlabel='pH'>

# %%
pd.DataFrame(os_train_df['pH'][stats.zscore(os_train_df['pH']) > 3]).sort_values(by='pH',ascending=True)
# Out:
#         pH
# 553   3.74
# 2711  3.74
# 1681  3.74
# 94    3.75
# 94    3.75
# 94    3.75
# 94    3.75
# 94    3.75
# 94    3.75
# 94    3.75
# 4259  3.75
# 4109  3.75
# 94    3.75
# 94    3.75
# 94    3.75
# 94    3.75
# 3025  3.76
# 3025  3.76
# 1385  3.77
# 1111  3.78
# 1111  3.78
# 2321  3.79
# 1255  3.81
# 1250  3.82
# 45    3.90
# 45    3.90
# 45    3.90
# 45    3.90
# 45    3.90
# 45    3.90
# 45    3.90
# 45    3.90
# 45    3.90
# 45    3.90
# 1316  4.01

# %%
print((os_train_df['pH']==0).sum())
(test_df['pH']==0).sum()
# Out:
# 0
# np.int64(0)

# %%
os_train_df['pH']=np.log(os_train_df['pH'])
test_df['pH'] = np.log(test_df['pH'])

# %%
pd.DataFrame(os_train_df.groupby('sulphates')['quality'].value_counts())
# Out:
#                    count
# sulphates quality
# 0.22      7            1
# 0.25      4            7
# 0.26      8           12
# 0.27      8           25
#           7            7
# ...                  ...
# 1.59      5            1
# 1.61      6            1
# 1.62      5            1
# 1.95      6            2
# 1.98      5            1
#
# [352 rows x 1 columns]

# %%
sns.scatterplot(data=train_df,x='sulphates',y='alcohol',hue='quality')
# Out:
# <Axes: xlabel='sulphates', ylabel='alcohol'>

# %%
sns.histplot(data=os_train_df,x='sulphates',hue='quality',multiple='stack')
# Out:
# <Axes: xlabel='sulphates', ylabel='Count'>

# %%
sns.barplot(data=train_df,x='sulphates',hue='quality')
# Out:
# <Axes: xlabel='sulphates'>

# %%
sns.boxplot(data=train_df,x='sulphates',hue='quality')
# Out:
# <Axes: xlabel='sulphates'>

# %%
pd.DataFrame(os_train_df['sulphates'][stats.zscore(os_train_df['sulphates']) > 3]).sort_values(by='sulphates',ascending=True)
# Out:
#       sulphates
# 1516       0.97
# 759        0.97
# 4012       0.98
# 1166       0.98
# 4000       0.98
# ...         ...
# 226        1.61
# 723        1.62
# 86         1.95
# 86         1.95
# 92         1.98
#
# [100 rows x 1 columns]

# %%
print((train_df['sulphates']==0).sum())
(test_df['sulphates']==0).sum()
# Out:
# 0
# np.int64(0)

# %%
os_train_df['sulphates']=np.log(os_train_df['sulphates'])
test_df['sulphates'] = np.log(test_df['sulphates'])

# %%
pd.DataFrame(os_train_df.groupby('alcohol')['quality'].value_counts())
# Out:
#                  count
# alcohol quality
# 8.00    5            1
# 8.40    3           59
#         5            2
# 8.50    3           72
#         6            6
# ...                ...
# 14.00   7            5
#         6            1
# 14.05   7            2
# 14.20   7            5
# 14.90   5            1
#
# [288 rows x 1 columns]

# %%
sns.scatterplot(data=train_df,y='sulphates',x='alcohol',hue='quality')
# Out:
# <Axes: xlabel='alcohol', ylabel='sulphates'>

# %%
sns.histplot(data=os_train_df,x='alcohol',hue='quality',multiple='stack')
# Out:
# <Axes: xlabel='alcohol', ylabel='Count'>

# %%
sns.histplot(data=os_train_df,x='alcohol',hue='quality',multiple='stack')
# Out:
# <Axes: xlabel='alcohol', ylabel='Count'>

# %%
sns.barplot(data=os_train_df,x='alcohol',hue='quality')
# Out:
# <Axes: xlabel='alcohol'>

# %%
sns.boxplot(data=os_train_df,x='alcohol',hue='quality')
# Out:
# <Axes: xlabel='alcohol'>

# %%
pd.DataFrame(os_train_df['alcohol'][stats.zscore(os_train_df['alcohol']) > 3]).sort_values(by='alcohol',ascending=True)
# Out:
#      alcohol
# 652     14.9

# %%
print((os_train_df['alcohol']==0).sum())
(test_df['alcohol']==0).sum()
# Out:
# 0
# np.int64(0)

# %%
os_train_df['alcohol']=np.log(os_train_df['alcohol'])
test_df['alcohol'] = np.log(test_df['alcohol'])

# %%
[i for i in my_df.columns]
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality',
#  'color_white']

# %%
# i am trying some feature enginering
os_train_df['total_acidity'] = os_train_df['fixed acidity'] + os_train_df['volatile acidity'] + os_train_df['citric acid']
test_df['total_acidity'] = test_df['fixed acidity'] + test_df['volatile acidity'] + test_df['citric acid']

# %%
# i split train test 
x_train = os_train_df.drop(columns=['quality'])
x_test = test_df.drop(columns=['quality'])

y_train = os_train_df['quality']
y_test = test_df['quality']

# %% [markdown]
# the number of outliers is very small, the model can already tolerate them.

# %%
# I will apply scaling because I’m going to use K-Nearest Neighbors.

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
mm = MinMaxScaler()
x_train_mm = pd.DataFrame(mm.fit_transform(x_train), columns=x_train.columns)
x_test_mm = pd.DataFrame(mm.transform(x_test), columns=x_test.columns)
# i use the minmax scaling before that i did all the outlier

# %%
x_train_mm = pd.DataFrame(x_train_mm, columns=x_train.columns)
x_test_mm = pd.DataFrame(x_test_mm, columns=x_test.columns)
#this code is change the column 1234 to normal column name

# %%
x_train_mm
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.416763          0.419946     0.222892        0.685952   0.335167
# 1          0.406563          0.658233     0.174699        0.327772   0.353651
# 2          0.554196          0.709907     0.367470        0.303728   0.597760
# 3          0.426816          0.485030     0.234940        0.616135   0.472378
# 4          0.364208          0.431709     0.108434        0.812031   0.353651
# ...             ...               ...          ...             ...        ...
# 9673       0.456134          0.289961     0.162651        0.792817   0.437620
# 9674       0.406563          0.395104     0.253012        0.262729   0.401766
# 9675       0.177622          0.475023     0.186747        0.174861   0.136411
# 9676       0.416763          0.381956     0.162651        0.684562   0.347649
# 9677       0.528787          0.252676     0.265060        0.796421   0.420370
#
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_model = KNeighborsClassifier(n_neighbors=5)
knn_model.fit(x_train_mm, y_train)

train_preds = knn_model.predict(x_train_mm)
test_preds = knn_model.predict(x_test_mm)

# %%
train_preds= knn_model.predict(x_train_mm)
test_preds = knn_model.predict(x_test_mm)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

# %%
#this function makes predictions and prints out various evaluation metrics
def model_evaluator(X_matrix, y_target, model):
    preds = model.predict(X_matrix)
    
    print(f"Accuracy score: {round(accuracy_score(y_target, preds),4)}")
    print(f"Precision score: {round(precision_score(y_target, preds, average='macro'),4)}")
    print(f"Recall score: {round(recall_score(y_target, preds, average='macro'),4)}")
    print(f"F1 score: {round(f1_score(y_target, preds, average='macro'),4)}")
    print(f"Confusion matrix: \n{confusion_matrix(y_target, preds)}")
    print(f"Classification report: \n{classification_report(y_target, preds)}")

# %%
model_evaluator(x_train_mm, y_train, knn_model)
# Out:
# Accuracy score: 0.8781
# Precision score: 0.8734
# Recall score: 0.8781
# F1 score: 0.8739
# Confusion matrix:
# [[1613    0    0    0    0    0]
#  [   0 1611    0    2    0    0]
#  [  19  121 1152  235   73   13]
#  [   8   35  222 1076  209   63]
#  [   2    4   27  107 1433   40]
#  [   0    0    0    0    0 1613]]
# Classification report:
#               precision    recall  f1-score   support
#
#            3       0.98      1.00      0.99      1613
#            4       0.91      1.00      0.95      1613
#            5       0.82      0.71      0.76      1613
#            6       0.76      0.67      0.71      1613
#            7       0.84      0.89      0.86      1613
#            8       0.93      1.00      0.97      1613
#
#     accuracy                           0.88      9678
#    macro avg       0.87      0.88      0.87      9678
# weighted avg       0.87      0.88      0.87      9678

# %%
model_evaluator(x_test_mm, y_test, knn_model)
# Out:
# Accuracy score: 0.4708
# Precision score: 0.3133
# Recall score: 0.3746
# F1 score: 0.3212
# Confusion matrix:
# [[  0   3   2   1   1   0]
#  [  4  14  28   6   4   1]
#  [  6  72 300 104  37   6]
#  [  2  41 169 273 191  42]
#  [  1   6  18  54 157  38]
#  [  0   1   0   3  19  21]]
# Classification report:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         7
#            4       0.10      0.25      0.14        57
#            5       0.58      0.57      0.58       525
#            6       0.62      0.38      0.47       718
#            7       0.38      0.57      0.46       274
#            8       0.19      0.48      0.28        44
#
#     accuracy                           0.47      1625
#    macro avg       0.31      0.37      0.32      1625
# weighted avg       0.53      0.47      0.48      1625

# %% [markdown]
# Accuracy score: 0.5077
# Precision score: 0.3479
# Recall score: 0.4312
# F1 score: 0.3672
# Confusion matrix:
# [[  0   3   2   0   1   0]
#  [  1  22  15   6   4   0]
#  [  4  50 318 115  48   5]
#  [  4  44 179 291 151  35]
#  [  1   5  23  57 170  25]
#  [  0   0   1   8  13  24]]
# Classification report:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         6
#            4       0.18      0.46      0.26        48
#            5       0.59      0.59      0.59       540
#            6       0.61      0.41      0.49       704
#            7       0.44      0.60      0.51       281
#            8       0.27      0.52      0.36        46
#
#     accuracy                           0.51      1625
#    macro avg       0.35      0.43      0.37      1625
# weighted avg       0.55      0.51      0.52      1625

# %%
from sklearn.model_selection import GridSearchCV

# %%
hyperparameters_dict = {'n_neighbors': [1,3,5,7,15],
                        'weights': ['uniform', 'distance'],
                        'metric': ['euclidean','manhattan','cosine']}

# %%
gridsearch_model = GridSearchCV(estimator=KNeighborsClassifier(),
                                param_grid=hyperparameters_dict,
                                verbose=3,
                                scoring = 'accuracy')

# %%
gridsearch_model.fit(x_train_mm, y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV 1/5] END metric=euclidean, n_neighbors=1, weights=uniform;, score=0.878 total time=   0.1s
# [CV 2/5] END metric=euclidean, n_neighbors=1, weights=uniform;, score=0.892 total time=   0.1s
# [CV 3/5] END metric=euclidean, n_neighbors=1, weights=uniform;, score=0.885 total time=   0.1s
# [CV 4/5] END metric=euclidean, n_neighbors=1, weights=uniform;, score=0.878 total time=   0.1s
# [CV 5/5] END metric=euclidean, n_neighbors=1, weights=uniform;, score=0.901 total time=   0.1s
# [CV 1/5] END metric=euclidean, n_neighbors=1, weights=distance;, score=0.878 total time=   0.1s
# [CV 2/5] END metric=euclidean, n_neighbors=1, weights=distance;, score=0.892 total time=   0.1s
# [CV 3/5] END metric=euclidean, n_neighbors=1, weights=distance;, score=0.885 total time=   0.1s
# [CV 4/5] END metric=euclidean, n_neighbors=1, weights=distance;, score=0.878 total time=   0.1s
# ...

# %%
best_model = gridsearch_model.best_estimator_

# %%
best_model
# Out:
# KNeighborsClassifier(metric='cosine', n_neighbors=1)

# %%
model_evaluator(x_train_mm, y_train, best_model)
# Out:
# Accuracy score: 1.0
# Precision score: 1.0
# Recall score: 1.0
# F1 score: 1.0
# Confusion matrix:
# [[1613    0    0    0    0    0]
#  [   0 1613    0    0    0    0]
#  [   0    0 1613    0    0    0]
#  [   0    0    0 1613    0    0]
#  [   0    0    0    0 1613    0]
#  [   0    0    0    0    0 1613]]
# Classification report:
#               precision    recall  f1-score   support
#
#            3       1.00      1.00      1.00      1613
#            4       1.00      1.00      1.00      1613
#            5       1.00      1.00      1.00      1613
#            6       1.00      1.00      1.00      1613
#            7       1.00      1.00      1.00      1613
#            8       1.00      1.00      1.00      1613
#
#     accuracy                           1.00      9678
#    macro avg       1.00      1.00      1.00      9678
# weighted avg       1.00      1.00      1.00      9678

# %%
model_evaluator(x_test_mm, y_test, best_model)
# Out:
# Accuracy score: 0.5643
# Precision score: 0.3739
# Recall score: 0.4054
# F1 score: 0.3847
# Confusion matrix:
# [[  0   1   4   2   0   0]
#  [  2  11  30  11   3   0]
#  [  1  21 375 106  18   4]
#  [  2  22 196 352 127  19]
#  [  0   2  16  78 159  19]
#  [  0   0   3   3  18  20]]
# Classification report:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         7
#            4       0.19      0.19      0.19        57
#            5       0.60      0.71      0.65       525
#            6       0.64      0.49      0.55       718
#            7       0.49      0.58      0.53       274
#            8       0.32      0.45      0.38        44
#
#     accuracy                           0.56      1625
#    macro avg       0.37      0.41      0.38      1625
# weighted avg       0.57      0.56      0.56      1625

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier()
rf_model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
model_evaluator(x_train,y_train,rf_model)
# Out:
# Accuracy score: 1.0
# Precision score: 1.0
# Recall score: 1.0
# F1 score: 1.0
# Confusion matrix:
# [[1613    0    0    0    0    0]
#  [   0 1613    0    0    0    0]
#  [   0    0 1613    0    0    0]
#  [   0    0    0 1613    0    0]
#  [   0    0    0    0 1613    0]
#  [   0    0    0    0    0 1613]]
# Classification report:
#               precision    recall  f1-score   support
#
#            3       1.00      1.00      1.00      1613
#            4       1.00      1.00      1.00      1613
#            5       1.00      1.00      1.00      1613
#            6       1.00      1.00      1.00      1613
#            7       1.00      1.00      1.00      1613
#            8       1.00      1.00      1.00      1613
#
#     accuracy                           1.00      9678
#    macro avg       1.00      1.00      1.00      9678
# weighted avg       1.00      1.00      1.00      9678

# %%
model_evaluator(x_test,y_test,rf_model)
# Out:
# Accuracy score: 0.6142
# Precision score: 0.4601
# Recall score: 0.4097
# F1 score: 0.4152
# Confusion matrix:
# [[  0   0   6   1   0   0]
#  [  1   8  40   7   1   0]
#  [  2   9 424  76  14   0]
#  [  0   3 202 373 138   2]
#  [  0   1  21  64 178  10]
#  [  0   0   3   7  19  15]]
# Classification report:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         7
#            4       0.38      0.14      0.21        57
#            5       0.61      0.81      0.69       525
#            6       0.71      0.52      0.60       718
#            7       0.51      0.65      0.57       274
#            8       0.56      0.34      0.42        44
#
#     accuracy                           0.61      1625
#    macro avg       0.46      0.41      0.42      1625
# weighted avg       0.62      0.61      0.60      1625

# %%
hyperparameters_dict1 = {
    'criterion' : ['gini','entropy'],
    'n_estimators' : [50,100],
    'min_samples_split' : [2,4,8],
    'min_samples_leaf' : [2,4,6],
    

}

# %%
gridsearch_model1 = GridSearchCV(
    estimator =RandomForestClassifier(),
    param_grid =hyperparameters_dict1,
    verbose=3,
    scoring = 'accuracy'
    )

# %%
gridsearch_model1.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV 1/5] END criterion=gini, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.905 total time=   0.8s
# [CV 2/5] END criterion=gini, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.899 total time=   0.6s
# [CV 3/5] END criterion=gini, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.895 total time=   0.6s
# [CV 4/5] END criterion=gini, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.895 total time=   0.5s
# [CV 5/5] END criterion=gini, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.901 total time=   0.6s
# [CV 1/5] END criterion=gini, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.900 total time=   1.0s
# [CV 2/5] END criterion=gini, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.898 total time=   1.1s
# ...

# %%
model_evaluator(x_train,y_train,gridsearch_model1)
# Out:
# Accuracy score: 0.9981
# Precision score: 0.9981
# Recall score: 0.9981
# F1 score: 0.9981
# Confusion matrix:
# [[1613    0    0    0    0    0]
#  [   0 1613    0    0    0    0]
#  [   0    1 1608    0    4    0]
#  [   0    0    8 1603    2    0]
#  [   0    0    2    1 1610    0]
#  [   0    0    0    0    0 1613]]
# Classification report:
#               precision    recall  f1-score   support
#
#            3       1.00      1.00      1.00      1613
#            4       1.00      1.00      1.00      1613
#            5       0.99      1.00      1.00      1613
#            6       1.00      0.99      1.00      1613
#            7       1.00      1.00      1.00      1613
#            8       1.00      1.00      1.00      1613
#
#     accuracy                           1.00      9678
#    macro avg       1.00      1.00      1.00      9678
# weighted avg       1.00      1.00      1.00      9678

# %%
model_evaluator(x_test,y_test,gridsearch_model1)
# Out:
# Accuracy score: 0.608
# Precision score: 0.4339
# Recall score: 0.4116
# F1 score: 0.4108
# Confusion matrix:
# [[  0   2   5   0   0   0]
#  [  1  10  38   6   2   0]
#  [  1   9 424  74  17   0]
#  [  0   6 209 364 133   6]
#  [  0   2  19  65 175  13]
#  [  0   0   0   9  20  15]]
# Classification report:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         7
#            4       0.34      0.18      0.23        57
#            5       0.61      0.81      0.70       525
#            6       0.70      0.51      0.59       718
#            7       0.50      0.64      0.56       274
#            8       0.44      0.34      0.38        44
#
#     accuracy                           0.61      1625
#    macro avg       0.43      0.41      0.41      1625
# weighted avg       0.62      0.61      0.60      1625

# %%
pd.DataFrame(gridsearch_model1.feature_names_in_,gridsearch_model1.best_estimator_.feature_importances_)
# Out:
#                              0
# 0.067969         fixed acidity
# 0.089506      volatile acidity
# 0.073392           citric acid
# 0.070256        residual sugar
# 0.077042             chlorides
# 0.098385   free sulfur dioxide
# 0.078952  total sulfur dioxide
# 0.087704               density
# 0.061713                    pH
# 0.076525             sulphates
# 0.125941               alcohol
# 0.005144           color_white
# 0.087473         total_acidity

# %% [markdown]
# The model performance was evaluated on the test dataset.
# Different values of K were tested to find the optimal balance between bias and variance.
# The final model demonstrates how distance-based classification behaves under different parameter choices.
